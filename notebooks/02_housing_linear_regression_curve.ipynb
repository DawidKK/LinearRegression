# %% [markdown]
# # Housing Price Curve with Pure Linear Regression
#
# This notebook trains a plain `LinearRegression` model on `sqft_living -> price_usd` without regularization, feature selection, or standardization.

# %%
from ml_training_practice.data import load_housing_prices_data
from ml_training_practice.modeling import train_housing_univariate_linear_regression
from ml_training_practice.visualization import plot_housing_linear_regression_result

# %% [markdown]
# ## 1) Load data

# %%
housing_data = load_housing_prices_data()
housing_data.head()

# %% [markdown]
# ## 2) Inspect columns

# %%
housing_data.columns.tolist()

# %% [markdown]
# ## 3) Split + 4) Train + 5) Evaluate

# %%
result = train_housing_univariate_linear_regression(test_size=0.2, random_state=42)
print(f"RMSE: {result.rmse:.2f}")
print(f"R^2: {result.r2:.3f}")

# %% [markdown]
# ## 6) Plot scatter + regression line

# %%
plot_housing_linear_regression_result(result)

# %% [markdown]
# ## 7) Coefficient and intercept interpretation

# %%
print(f"Coefficient (year_built): {result.coefficient:.2f}")
print(f"Intercept: {result.intercept:.2f}")
print("Interpretation: each +1 sqft is associated with approximately coefficient USD change in price.")
